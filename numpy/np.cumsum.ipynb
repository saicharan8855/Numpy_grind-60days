# %% [markdown]
# ### np.cumsum

# %%
import itertools

# %%
def get_shape(a):
    if not isinstance(a , list): 
        return ()
    if len(a) == 0: 
        return (0 , )
    inner_shape = get_shape(a[0])

    for i in range(1 , len(a)):
        if get_shape(a[i]) != inner_shape:
            raise ValueError(
                f"Jagged array detected : the shape of first row is {inner_shape}" , 
                f"but row {i} has shape {get_shape(a[i])}"
            )

    return (len(a) , ) + inner_shape

def get_ndim(a):
    return len(get_shape(a))

def flatten(a): 
    result = []
    if not isinstance(a , list):
        return [a]
    for item in a:
        result.extend(flatten(item))
    return result

def deep_copy(a):
    if isinstance(a , list):
        return [deep_copy(item) for item in a]
    return a 

def cast_all(a , dtype):
    if isinstance( a , list):
        return [cast_all(x , dtype) for x in a]

    try:
        return dtype(a)
    except ValueError:
        try:
            return dtype(float(a))
        except (ValueError , TypeError): 
            raise TypeError(
                f"cannot cast element {a} to {dtype.__name__}"
            )
    except TypeError: 
        raise TypeError(
            f"cannot cast element {a} (type : {type(a).__name__})"
            f"to {dtype.__name__}"
        )

def get_element(a , indices): 
    depth = 0

    for idx in indices:
        if not isinstance(a , list): 
            raise TypeError(f"expected a list at depth {depth} , but git {type(a).__name__}")
        if idx >= len(a) or idx < -len(a):
            raise IndexError(f"at depth {depth} index {idx} is out of range for {len(a)}")

        a = a[idx]
        depth += 1

    return a

def set_element(a, indices, value):
    depth = 0
    for idx in indices[:-1]:
        if not isinstance(a, list):
            raise TypeError(f"at depth {depth}: expected list, got {type(a).__name__}")

        if idx >= len(a) or idx < -len(a):
            raise IndexError(f"at depth {depth}: index {idx} out of range")

        a = a[idx]
        depth += 1

    last_idx = indices[-1]

    if not isinstance(a, list):
        raise TypeError("too many indices")

    if last_idx >= len(a) or last_idx < -len(a):
        raise IndexError(f"final index {last_idx} out of range")

    a[last_idx] = value

# %%
def np_cumsum(a , axis = None , dtype = None , out = None): 
    if not isinstance( a , list):
        raise ValueError(f"expected list but got {type(a).__name__}")
    shape = get_shape(a)
    ndim = len(shape)

    if ndim == 0: 
        raise ValueError("np_cumsum doesnot support 0 - d input")
    if dtype is not None:
        a = cast_all(a , dtype)

    else:
        flat = flatten(a)
        if flat and isinstance(flat[0] , float):
            dtype = float
        else:
            dtype = int
        a = cast_all(a , dtype)

    if axis is None:
        flat = flatten(a)
        if len(flat) == 0:
            return []
        result = flat[:]
        for i in range(1, len(result)):
            result[i] = result[i] + result[i - 1]
        if out is not None:
            if len(out) != len(result):
                raise ValueError("out shape doesn't match result shape")
            for i in range(len(result)):
                out[i] = result[i]
            return out
        return result

    if axis < -ndim or axis >= ndim:
        raise IndexError(
            f"axis {axis} is out of bounds for array of dimension {ndim}"
        )
    if axis < 0:
        axis = ndim + axis

    if 0 in shape:
        return deep_copy(a)

    result = deep_copy(a)
    other_dims = []
    for i in range(ndim):
        if i != axis:
            other_dims.append(range(shape[i]))

    for combo in itertools.product(*other_dims):
        for ax_i in range(1, shape[axis]):

            current_idx = list(combo)
            current_idx.insert(axis, ax_i)

            prev_idx = list(combo)
            prev_idx.insert(axis, ax_i - 1)

            current_value = get_element(result, current_idx)
            previous_value = get_element(result, prev_idx)
            
            new_value = current_value + previous_value
            set_element(result, current_idx, new_value)

    if out is not None:
        if get_shape(out) != get_shape(result):
            raise ValueError("out shape doesn't match result shape")
        for combo in itertools.product(*[range(s) for s in shape]):
            set_element(out, list(combo), get_element(result, list(combo)))
        return out

    return result

# %% [markdown]
# ### test_cases :

# %%
print(np_cumsum([1, 2, 3, 4]))
print(np_cumsum([-1, -2, -3])) 
print(np_cumsum([])) 
print(np_cumsum([3, -1, 4, -1, 5])) 
print(np_cumsum([[1,2],[3,4]]))
print(np_cumsum([[1,2],[3,4]], axis=0)) 
print(np_cumsum([[1,2],[3,4]], axis=1)) 
print(np_cumsum([[1,2],[3,4]], axis=-1))
print(np_cumsum([1, 2, 3], dtype=float)) 
print(np_cumsum([1.5, 2.5], dtype=int))
# Out:
# [1, 3, 6, 10]
# [-1, -3, -6]
# []
# [3, 2, 6, 5, 10]
# [1, 3, 6, 10]
# [[1, 2], [4, 6]]
# [[1, 3], [3, 7]]
# [[1, 3], [3, 7]]
# [1.0, 3.0, 6.0]
# [1, 3]

# %%
out = [0, 0, 0]
np_cumsum([1, 2, 3], out=out)
print(out)
# Out:
# [1, 3, 6]

# %%
arr = [1, 2, 3]
np_cumsum(arr, out=arr)
print(arr)
# Out:
# [1, 3, 6]

# %%
print(np_cumsum([[1,2],[3,4,5]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(np_cumsum([[1,2],[3,4,5]]))
#
# Cell In[4], line 4, in np_cumsum(a, axis, dtype, out)
#       2 if not isinstance( a , list):
#       3     raise ValueError(f"expected list but got {type(a).__name__}")
# ----> 4 shape = get_shape(a)
#       5 ndim = len(shape)
#       7 if ndim == 0:
#
# Cell In[3], line 10, in get_shape(a)
#       8 for i in range(1 , len(a)):
#       9     if get_shape(a[i]) != inner_shape:
# ---> 10         raise ValueError(
#      11             f"Jagged array detected : the shape of first row is {inner_shape}" ,
#      12             f"but row {i} has shape {get_shape(a[i])}"
#      13         )
#      15 return (len(a) , ) + inner_shape
#
# ValueError: ('Jagged array detected : the shape of first row is (2,)', 'but row 1 has shape (3,)')

# %%
print(np_cumsum([[1,2],[3,4]], axis=5))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(np_cumsum([[1,2],[3,4]], axis=5))
#
# Cell In[4], line 36, in np_cumsum(a, axis, dtype, out)
#      33     return result
#      35 if axis < -ndim or axis >= ndim:
# ---> 36     raise IndexError(
#      37         f"axis {axis} is out of bounds for array of dimension {ndim}"
#      38     )
#      39 if axis < 0:
#      40     axis = ndim + axis
#
# IndexError: axis 5 is out of bounds for array of dimension 2

# %%
print(np_cumsum(["a","b"], dtype=int))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 38, in cast_all(a, dtype)
#      37 try:
# ---> 38     return dtype(a)
#      39 except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'a'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 41, in cast_all(a, dtype)
#      40 try:
# ---> 41     return dtype(float(a))
#      42 except (ValueError , TypeError):
#
# ValueError: could not convert string to float: 'a'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(np_cumsum(["a","b"], dtype=int))
#
# Cell In[4], line 10, in np_cumsum(a, axis, dtype, out)
#       8     raise ValueError("np_cumsum doesnot support 0 - d input")
#       9 if dtype is not None:
# ---> 10     a = cast_all(a , dtype)
#      12 else:
#      13     flat = flatten(a)
#
# Cell In[3], line 35, in cast_all(a, dtype)
#      33 def cast_all(a , dtype):
#      34     if isinstance( a , list):
# ---> 35         return [cast_all(x , dtype) for x in a]
#      37     try:
#      38         return dtype(a)
#
# Cell In[3], line 43, in cast_all(a, dtype)
#      41         return dtype(float(a))
#      42     except (ValueError , TypeError):
# ---> 43         raise TypeError(
#      44             f"cannot cast element {a} to {dtype.__name__}"
#      45         )
#      46 except TypeError:
#      47     raise TypeError(
#      48         f"cannot cast element {a} (type : {type(a).__name__})"
#      49         f"to {dtype.__name__}"
#      50     )
#
# TypeError: cannot cast element a to int

# %%
print(np_cumsum([1,2,3], out=[0,0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(np_cumsum([1,2,3], out=[0,0]))
#
# Cell In[4], line 29, in np_cumsum(a, axis, dtype, out)
#      27 if out is not None:
#      28     if len(out) != len(result):
# ---> 29         raise ValueError("out shape doesn't match result shape")
#      30     for i in range(len(result)):
#      31         out[i] = result[i]
#
# ValueError: out shape doesn't match result shape
